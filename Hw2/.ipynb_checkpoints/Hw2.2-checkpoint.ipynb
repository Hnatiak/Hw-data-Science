# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2=pd.read_csv('2017_jun_final.csv')
df2.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# 1                 430                           130  Харків  більше 1000 осіб
# 2                2500                           800    Київ      до 1000 осіб
# 3                2000                           400   Одеса       до 200 осіб
# 4                4500                           500    Інше        до 10 осіб
#
#    ... Ще студент                    Рівень англійської  \
# 0  ...       True    Pre-intermediate (нище середнього)
# 1  ...       True  Upper-Intermediate (вище середнього)
# 2  ...      False               Intermediate (середній)
# 3  ...      False    Pre-intermediate (нище середнього)
# 4  ...      False               Intermediate (середній)
#
#                    Предметна область      Дата заповнення  \
# 0                      iOS,eCommerce  12/06/2017 12:38:08
# 1                       Веб-розробка  12/06/2017 12:42:51
# 2  Веб-розробка,Корпоративні системи  12/06/2017 13:02:47
# 3  Desktop Applications,Веб-розробка  12/06/2017 13:03:01
# 4  Desktop Applications,Веб-розробка  12/06/2017 13:03:47
#
#                                           User.Agent   exp current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5             0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0             0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0             1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0             4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0             0.5
#
#   salary Валюта  cls
# 0    400    NaN   QA
# 1    430    NaN   QA
# 2   2500    NaN  DEV
# 3   2000    NaN  DEV
# 4   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %%
df2.shape
# Out:
# (8704, 25)

# %%
df2.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %%
pd.isnull(df2).sum()/8704*100
# Out:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Спеціалізація                       82.938879
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Університет                          4.113051
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Предметна область                    2.562040
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# Валюта                              99.885110
# cls                                 18.083640
# dtype: float64

# %%
df_without_nan = df2.drop(['Спеціалізація', 'Університет', 'Предметна область', 'Валюта', 'cls'], axis=1)
# df_without_nan.head()
pd.isnull(df_without_nan).sum()/8704*100
# Out:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# dtype: float64

# %%
df2_dropana=df2.dropna()
df2_dropana.shape
# Out:
# (0, 25)

# %%
python_data=df2[df2["Мова програмування"]=='Python']
python_data
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 12      13         Software Engineer             Python           NaN
# 68      69         Software Engineer             Python           NaN
# 87      88  Junior Software Engineer             Python           NaN
# 114    115  Junior Software Engineer             Python           NaN
# 143    144  Junior Software Engineer             Python           NaN
# ...    ...                       ...                ...           ...
# 8546  8547         Software Engineer             Python           NaN
# 8625  8626         Software Engineer             Python           NaN
# 8635  8636  Senior Software Engineer             Python           NaN
# 8673  8674  Junior Software Engineer             Python           NaN
# 8695  8696         Software Engineer             Python           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# 114                      1.5                              0.5
# 143                        1                                1
# ...                      ...                              ...
# 8546                       5                                1
# 8625                       4                                1
# 8635       10 і більше років                  менше 3 місяців
# 8673                     0.5                              0.5
# 8695                       1                              0.5
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців      Місто  \
# 12                   800                           200       Київ
# 68                   900                           900       Київ
# 87                   600                             0       Київ
# 114                  685                           250       Київ
# 143                  750                           250       Київ
# ...                  ...                           ...        ...
# 8546                2000                           800  Запоріжжя
# 8625                1750                             0       Київ
# 8635                4000                          1300  Віддалено
# 8673                 350                            50       Київ
# 8695                1500                          1000       Київ
#
#        Розмір компанії  ... Ще студент                    Рівень англійської  \
# 12          до 50 осіб  ...      False    Pre-intermediate (нище середнього)
# 68          до 10 осіб  ...       True  Upper-Intermediate (вище середнього)
# 87          до 10 осіб  ...       True  Upper-Intermediate (вище середнього)
# 114       до 1000 осіб  ...      False               Intermediate (середній)
# 143         до 10 осіб  ...       True  Upper-Intermediate (вище середнього)
# ...                ...  ...        ...                                   ...
# 8546        до 50 осіб  ...      False               Intermediate (середній)
# 8625  більше 1000 осіб  ...      False               Intermediate (середній)
# 8635        до 10 осіб  ...      False  Upper-Intermediate (вище середнього)
# 8673        до 50 осіб  ...      False               Intermediate (середній)
# 8695        до 10 осіб  ...      False               Intermediate (середній)
#
#                  Предметна область      Дата заповнення  \
# 12               Веб-розробка,Інше  12/06/2017 13:05:54
# 68                    Веб-розробка  12/06/2017 13:11:17
# 87          Веб-розробка,eCommerce  12/06/2017 13:12:25
# 114                           Інше  12/06/2017 13:14:52
# 143                   Веб-розробка  12/06/2017 13:19:10
# ...                            ...                  ...
# 8546                  Веб-розробка  10/07/2017 14:11:26
# 8625                  Веб-розробка  11/07/2017 16:15:40
# 8635                  Веб-розробка  11/07/2017 17:51:36
# 8673                  Веб-розробка   12/07/2017 9:37:16
# 8695  Фінанси та банкінг,eCommerce  12/07/2017 14:39:21
#
#                                              User.Agent   exp current_job_exp  \
# 12    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   1.0             0.0
# 68    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.5             0.5
# 87    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   0.5             0.5
# 114   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.5             0.5
# 143   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0             1.0
# ...                                                 ...   ...             ...
# 8546  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0             1.0
# 8625  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   4.0             1.0
# 8635  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  10.0             0.0
# 8673  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   0.5             0.5
# 8695  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0             0.5
#
#      salary Валюта  cls
# 12      800    NaN  DEV
# 68      900    NaN  DEV
# 87      600    NaN  DEV
# 114     685    NaN  DEV
# 143     750    NaN  DEV
# ...     ...    ...  ...
# 8546   2000    NaN  DEV
# 8625   1750    NaN  DEV
# 8635   4000    NaN  DEV
# 8673    350    NaN  DEV
# 8695   1500    NaN  DEV
#
# [207 rows x 25 columns]

# %%
python_data.shape
# Out:
# (207, 25)

# %%
grouping_columns=['Посада']
columns_to_show=["Зарплата на місяць"]
grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.min, np.max])
grouped_df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10508\2880289826.py:3: FutureWarning: The provided callable <function min at 0x0000022B3EA43560> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.min, np.max])
# C:\Users\User\AppData\Local\Temp\ipykernel_10508\2880289826.py:3: FutureWarning: The provided callable <function max at 0x0000022B3EA43420> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.min, np.max])
#                          Зарплата на місяць
#                                         min   max
# Посада
# Junior Software Engineer                100  1250
# Senior Software Engineer               1300  9200
# Software Engineer                       500  5400
# System Architect                       3000  5000
# Technical Lead                         1425  6200

# %%
grouping_columns=['Посада']
columns_to_show=["Зарплата на місяць"]
grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.mean, np.min, np.max])
grouped_df=grouped_df.sort_values(by=('Зарплата на місяць', 'mean'))
grouped_df.plot(kind='bar', label=['average', 'min', 'max'])
plt.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10508\634676769.py:3: FutureWarning: The provided callable <function mean at 0x0000022B3EA43E20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.mean, np.min, np.max])
# C:\Users\User\AppData\Local\Temp\ipykernel_10508\634676769.py:3: FutureWarning: The provided callable <function min at 0x0000022B3EA43560> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.mean, np.min, np.max])
# C:\Users\User\AppData\Local\Temp\ipykernel_10508\634676769.py:3: FutureWarning: The provided callable <function max at 0x0000022B3EA43420> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped_df=python_data.groupby(grouping_columns)[columns_to_show].agg([np.mean, np.min, np.max])

# %%
def fill_avg_salary(row):
    return python_data[python_data['Посада']==row['Посада']]["Зарплата на місяць"].mean()

fill_avg_series=python_data.apply(fill_avg_salary, axis=1)
python_data.insert(loc=len(python_data.columns), column='Середня зарплата', value=fill_avg_series)
python_data
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 12      13         Software Engineer             Python           NaN
# 68      69         Software Engineer             Python           NaN
# 87      88  Junior Software Engineer             Python           NaN
# 114    115  Junior Software Engineer             Python           NaN
# 143    144  Junior Software Engineer             Python           NaN
# ...    ...                       ...                ...           ...
# 8546  8547         Software Engineer             Python           NaN
# 8625  8626         Software Engineer             Python           NaN
# 8635  8636  Senior Software Engineer             Python           NaN
# 8673  8674  Junior Software Engineer             Python           NaN
# 8695  8696         Software Engineer             Python           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# 114                      1.5                              0.5
# 143                        1                                1
# ...                      ...                              ...
# 8546                       5                                1
# 8625                       4                                1
# 8635       10 і більше років                  менше 3 місяців
# 8673                     0.5                              0.5
# 8695                       1                              0.5
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців      Місто  \
# 12                   800                           200       Київ
# 68                   900                           900       Київ
# 87                   600                             0       Київ
# 114                  685                           250       Київ
# 143                  750                           250       Київ
# ...                  ...                           ...        ...
# 8546                2000                           800  Запоріжжя
# 8625                1750                             0       Київ
# 8635                4000                          1300  Віддалено
# 8673                 350                            50       Київ
# 8695                1500                          1000       Київ
#
#        Розмір компанії  ...                    Рівень англійської  \
# 12          до 50 осіб  ...    Pre-intermediate (нище середнього)
# 68          до 10 осіб  ...  Upper-Intermediate (вище середнього)
# 87          до 10 осіб  ...  Upper-Intermediate (вище середнього)
# 114       до 1000 осіб  ...               Intermediate (середній)
# 143         до 10 осіб  ...  Upper-Intermediate (вище середнього)
# ...                ...  ...                                   ...
# 8546        до 50 осіб  ...               Intermediate (середній)
# 8625  більше 1000 осіб  ...               Intermediate (середній)
# 8635        до 10 осіб  ...  Upper-Intermediate (вище середнього)
# 8673        до 50 осіб  ...               Intermediate (середній)
# 8695        до 10 осіб  ...               Intermediate (середній)
#
#                  Предметна область      Дата заповнення  \
# 12               Веб-розробка,Інше  12/06/2017 13:05:54
# 68                    Веб-розробка  12/06/2017 13:11:17
# 87          Веб-розробка,eCommerce  12/06/2017 13:12:25
# 114                           Інше  12/06/2017 13:14:52
# 143                   Веб-розробка  12/06/2017 13:19:10
# ...                            ...                  ...
# 8546                  Веб-розробка  10/07/2017 14:11:26
# 8625                  Веб-розробка  11/07/2017 16:15:40
# 8635                  Веб-розробка  11/07/2017 17:51:36
# 8673                  Веб-розробка   12/07/2017 9:37:16
# 8695  Фінанси та банкінг,eCommerce  12/07/2017 14:39:21
#
#                                              User.Agent   exp  \
# 12    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   1.0
# 68    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.5
# 87    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   0.5
# 114   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.5
# 143   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# ...                                                 ...   ...
# 8546  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0
# 8625  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   4.0
# 8635  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  10.0
# 8673  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   0.5
# 8695  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
#
#       current_job_exp salary Валюта  cls Середня зарплата
# 12                0.0    800    NaN  DEV      1799.070000
# 68                0.5    900    NaN  DEV      1799.070000
# 87                0.5    600    NaN  DEV       560.841270
# 114               0.5    685    NaN  DEV       560.841270
# 143               1.0    750    NaN  DEV       560.841270
# ...               ...    ...    ...  ...              ...
# 8546              1.0   2000    NaN  DEV      1799.070000
# 8625              1.0   1750    NaN  DEV      1799.070000
# 8635              0.0   4000    NaN  DEV      3387.096774
# 8673              0.5    350    NaN  DEV       560.841270
# 8695              0.5   1500    NaN  DEV      1799.070000
#
# [207 rows x 26 columns]

# %%
python_data['Середня зарплата'].describe()
# Out:
# count     207.000000
# mean     1753.937198
# std       996.562606
# min       560.841270
# 25%       560.841270
# 50%      1799.070000
# 75%      1799.070000
# max      4000.000000
# Name: Середня зарплата, dtype: float64

# %%
python_data.to_csv('2017_jun_with_average_salary.csv')

# %%
pd.Categorical(python_data['Рівень англійської'], categories=['елементарний', 'нище середнього', 'середній', 'вище середнього', 'просунутий'], ordered=True)
plt.figure(figsize=(8, 4))
sns.swarmplot(x='Рівень англійської', y='salary', hue='Посада', data=python_data)
plt.title('Зарплата в залежності від знань англійської мови')
plt.xlabel('Рівень англійської мови')
plt.ylabel('Зарплата')
plt.show()

# %%
# python_data['Загальний досвід роботи']=python_data['Загальний досвід роботи'].astype('float64')
# plt.figure(figsize=(8, 4))
# sns.scatterplot(x='Загальний досвід роботи', y='salary', data=python_data)
# plt.title('Зарплата в залежності від досвіду роботи')
# plt.xlabel('Опыт работы, лет')
# plt.ylabel('Зарплата')
# plt.show()


python_data['Загальний досвід роботи'] = python_data['Загальний досвід роботи'].astype(str)
python_data['Загальний досвід роботи'].replace(to_replace="10 і більше років", value="10", inplace=True)
python_data['Загальний досвід роботи'].replace(to_replace="менше 3 місяців", value="0", inplace=True)
python_data['Загальний досвід роботи'] = python_data['Загальний досвід роботи'].astype(float)
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Загальний досвід роботи', y='salary', data=python_data)
plt.title('Зарплата в залежності від досвіду роботи')
plt.xlabel('Досвід роботи і роки')
plt.ylabel('Зарплата')
plt.show()
